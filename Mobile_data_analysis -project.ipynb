# %%
import pandas as pd
df=pd.read_csv(r"D:\Christy\Datas\train.csv")
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# # Create Price column

# %%
import random
t=[]
for i in df["price_range"]:
    if i==0:
        price=random.randrange(2000,5000)
        t.append(price)
    elif i==1:
        price=random.randrange(5000,8000)
        t.append(price)
    elif i==2:
        price=random.randrange(8000,15000)
        t.append(price)
    else:
        price=random.randrange(15000,25000)
        t.append(price)
df["Price"]=pd.DataFrame({"Price":t})
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %% [markdown]
# # 1.which mobiles are more used blue_tooth or non blue_tooth,draw pie chart

# %%
import matplotlib.pyplot as plt
values=df["blue"].value_counts()
color=("r","green")
label=("Non_Bluetppth","Bluetooth")
plt.pie(values,colors=color,labels=label,autopct="%0.2f%%")
plt.title("Usage of Bluetooth")
plt.show()

# %% [markdown]
# # 2. What is the price for 64 GB internal memory mobile phones

# %%
df[df["int_memory"]==64]["Price"].mean()
# Out:
# 11845.677419354839

# %% [markdown]
# # 3. What is the difference of ram with respect to the price_range

# %%
import numpy as np
import matplotlib.pyplot as plt
xvalues=df["price_range"]
yvalues=df["ram"]
plt.bar(xvalues,yvalues)
plt.title("Ram of mobile phones withrespect to price_range")
plt.xlabel("Price_range")
plt.ylabel("Ram")
plt.show()

# %% [markdown]
# # 4. What are the features of dual_sim and high range mobile phones

# %%
import numpy as np
df3=np.where((df["dual_sim"]==1) & (df["price_range"]==3))
df31=df.loc[df3]
df31[["battery_power","int_memory","m_dep","mobile_wt","n_cores","fc","pc","px_height","px_width","ram","sc_h","sc_w","talk_time"]].describe()
# Out:
#        battery_power  int_memory       m_dep   mobile_wt     n_cores  \
# count     265.000000  265.000000  265.000000  265.000000  265.000000
# mean     1327.532075   33.362264    0.486415  134.645283    4.332075
# std       431.656578   17.956305    0.299944   35.411363    2.268674
# min       503.000000    2.000000    0.100000   80.000000    1.000000
# 25%       946.000000   16.000000    0.200000  103.000000    2.000000
# 50%      1397.000000   35.000000    0.500000  131.000000    4.000000
# 75%      1703.000000   49.000000    0.800000  166.000000    6.000000
# max      1994.000000   64.000000    1.000000  200.000000    8.000000
#
#                fc          pc    px_height     px_width          ram  \
# count  265.000000  265.000000   265.000000   265.000000   265.000000
# mean     4.007547    9.856604   711.158491  1365.328302  3483.988679
# std      4.310832    6.128223   450.734507   420.939446   366.537933
# ...

# %% [markdown]
# # 5. if ram >3500 then price is

# %%
df[df["ram"]>=3500][["ram","price_range","Price"]].mean()
# Out:
# ram             3756.222222
# price_range        2.937037
# Price          19206.751852
# dtype: float64

# %% [markdown]
# # 6. Usage of core processors with respect to price_range

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
values1=df[df["price_range"]==0]["n_cores"].value_counts()
values2=df[df["price_range"]==1]["n_cores"].value_counts()
values3=df[df["price_range"]==2]["n_cores"].value_counts()
values4=df[df["price_range"]==3]["n_cores"].value_counts()
plt.plot(values1,'go--', linewidth=2, markersize=8)
plt.plot(values2,'rs-',linewidth=3,markersize=8)
plt.plot(values3,'b^-', linewidth=2, markersize=8)
plt.plot(values4,'m*--', linewidth=2, markersize=12)
plt.title("Relation between price and number of core processors",loc="center")
plt.ylabel("Usages of core processor",loc="center")
plt.xlabel("Number of cores of processor",loc="center")
plt.grid()
plt.legend(["Price_range_0","Price_range_1","Price_range_2","Price_range_3"],loc="best")
plt.show()

# %% [markdown]
# # 7. what range of primary and front camera mobile get for price 10000

# %%
import numpy as np
dfc=np.where((df["Price"]>=10000) & (df["Price"]<=12000))
dfc1=df.loc[dfc]
print("Primary camera range :",dfc1["pc"].mean())
print("front camera range :",dfc1["fc"].mean())
print("Average price :",dfc1["Price"].mean())
# Out:
# Primary camera range : 10.182481751824817
# front camera range : 4.868613138686132
# Average price : 10959.372262773722

# %% [markdown]
# # 8. what are the features of 10000 rupee phone

# %%
df[df["price_range"]==2].describe()
# Out:
#        battery_power        blue  clock_speed    dual_sim         fc  \
# count     500.000000  500.000000   500.000000  500.000000  500.00000
# mean     1228.320000    0.486000     1.529800    0.498000    4.49800
# std       452.863065    0.500305     0.804404    0.500497    4.34739
# min       501.000000    0.000000     0.500000    0.000000    0.00000
# 25%       816.500000    0.000000     0.700000    0.000000    1.00000
# 50%      1219.500000    0.000000     1.500000    0.000000    3.00000
# 75%      1635.750000    1.000000     2.200000    1.000000    7.00000
# max      1998.000000    1.000000     3.000000    1.000000   18.00000
#
#            four_g  int_memory       m_dep   mobile_wt     n_cores  ...  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  ...
# mean     0.494000   30.920000    0.490800  143.614000    4.682000  ...
# std      0.500465   18.441958    0.286215   34.320326    2.262546  ...
# ...

# %% [markdown]
# # 9. What is the average price for dual_sim, bluetooth, wifi, touch_screen and 4G mobile phones

# %%
import numpy as np
dfp=np.where((df["touch_screen"]==1) & (df["four_g"]==1) & (df["wifi"]==1) & (df["dual_sim"]==1) & (df["blue"]==1))
dfp1=df.loc[dfp]
for i in dfp1["price_range"].unique():
    print(f"If price_range is {i} then features are")
    print("Average ram is :",dfp1[dfp1["price_range"]==i]["ram"].mean())
    print("Average primary camera is :",dfp1[dfp1["price_range"]==i]["pc"].mean())
    print("Average front camera is :",dfp1[dfp1["price_range"]==i]["fc"].mean())
    print("Number of core processors is :",dfp1[dfp1["price_range"]==i]["n_cores"].mean())
    print("Average screen height is :",dfp1[dfp1["price_range"]==i]["sc_h"].mean())
    print("Average screen width is :",dfp1[dfp1["price_range"]==i]["sc_w"].mean())
    print("Average battery_power is :",dfp1[dfp1["price_range"]==i]["battery_power"].mean())
    print("Average price is :",dfp1[dfp1["price_range"]==i]["Price"].mean())
    print("")
# Out:
# If price_range is 2 then features are
# Average ram is : 2750.5555555555557
# Average primary camera is : 6.888888888888889
# Average front camera is : 3.0
# Number of core processors is : 3.888888888888889
# Average screen height is : 13.11111111111111
# Average screen width is : 5.333333333333333
# Average battery_power is : 1128.111111111111
# Average price is : 13367.0
#
# If price_range is 3 then features are
# Average ram is : 3538.8333333333335
# Average primary camera is : 10.733333333333333
# Average front camera is : 4.166666666666667
# Number of core processors is : 5.033333333333333
# Average screen height is : 13.066666666666666
# Average screen width is : 6.333333333333333
# Average battery_power is : 1276.3333333333333
# Average price is : 20069.5
#
# If price_range is 1 then features are
# Average ram is : 1879.5555555555557
# Average primary camera is : 9.833333333333334
# Average front camera is : 4.222222222222222
# Number of core processors is : 4.833333333333333
# ...

# %% [markdown]
# # 10. What are the lowest and highest features of low_range mobile phones

# %%
print("Lowest features of low_range mobile phones is ")
print(df[df["price_range"]==0].min())
print("")
print("Highest features of low_range mobile phones is ")
print(df[df["price_range"]==0].max())
# Out:
# Lowest features of low_range mobile phones is
# battery_power     503.0
# blue                0.0
# clock_speed         0.5
# dual_sim            0.0
# fc                  0.0
# four_g              0.0
# int_memory          2.0
# m_dep               0.1
# mobile_wt          80.0
# n_cores             1.0
# pc                  0.0
# px_height           1.0
# px_width          500.0
# ram               256.0
# sc_h                5.0
# sc_w                0.0
# talk_time           2.0
# three_g             0.0
# touch_screen        0.0
# wifi                0.0
# price_range         0.0
# Price            2003.0
# dtype: float64
#
# Highest features of low_range mobile phones is
# battery_power    1994.0
# blue                1.0
# clock_speed         3.0
# dual_sim            1.0
# fc                 19.0
# four_g              1.0
# int_memory         64.0
# m_dep               1.0
# mobile_wt         200.0
# n_cores             8.0
# pc                 20.0
# px_height        1878.0
# ...

# %% [markdown]
# # 11. Which type of mobile phones are most saling

# %%
import matplotlib.pyplot as plt
values=df["price_range"].value_counts()
color=("r","green","b","c")
label=("low","medium_level","high","best")
plt.pie(values,colors=color,labels=label,autopct="%0.2f%%")
plt.title("Usage of Price_range")
plt.show()

# %% [markdown]
# # 12. Which mobile has highest battery storage dual_sim or single_sim

# %%
# Creating battery_range column

import pandas as pd
s=[]
for r in df["battery_power"]:
    if 1000>=r>=500:
        s.append("poor")
    elif 1500>=r>1000:
        s.append("average")
    else:
        s.append("good")
df["battery_range"]=pd.DataFrame({"battery_range":s})
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...   ram  sc_h  sc_w  talk_time  three_g  \
# ...

# %%
import numpy as np

r=[]
n=0
l=0
m=0
for k in df[df["dual_sim"]==1]["battery_range"]:
    if k=="poor":
        n+=1
    elif k=="average":
        l+=1
    else:
        m+=1
r.append(n)
r.append(l)
r.append(m)
          
v=[]
w=0
x=0
y=0

for k in df[df["dual_sim"]==0]["battery_range"]:
    if k=="poor":
        w+=1
    elif k=="average":
        x+=1
    else:
        y+=1

v.append(w)
v.append(x)
v.append(y)

import matplotlib.pyplot as plt
import pandas as pd 
divisions=[1,2,3]
dual_sim_batt=r
single_sim_batt=v
index=np.arange(3)
width=0.20
plt.bar(index,dual_sim_batt,width,color='b',label="Dual SIM Battery",tick_label=["poor","avg","good"])
plt.bar(index+width,single_sim_batt,width,color='r',label="Single SIM Battery")

plt.title("Dual and Single SIM battery usage")
plt.xlabel("Bttery range")
plt.ylabel("Battery level")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# # 13. Which mobile has the highest talk_time depends upon battery_range

# %%
import seaborn as sns
import matplotlib.pyplot as plt


df0=df[df["battery_range"]=="poor"]
df1=df[df["battery_range"]=="average"]
df2=df[df["battery_range"]=="good"]

plt.figure(figsize=(15,18))
plt.subplot(2,2,1)
sns.countplot(x="talk_time",data=df0)
plt.title("Low_range")


plt.subplot(2,2,2)
sns.countplot(x="talk_time",data=df1)
plt.title("Medium_range")


plt.subplot(2,2,3)
sns.countplot(x="talk_time",data=df2)
plt.title("High_range")

plt.suptitle("Mixed Plots")
plt.show()

# %% [markdown]
# # 14. Screen size for dual_sim mobile phones with respect to the price_range

# %%
import numpy as np
import matplotlib.pyplot as plt

count=range(0,4)

for n in count:
    dflp=np.where((df["dual_sim"]==1) & (df["price_range"]==n))
    dflp1=df.loc[dflp]
    box_data=dflp1[["sc_h","sc_w"]]
    labels=["screen_height","screen_width"]
    color=['r','c']
    box=plt.boxplot(box_data,sym='p',labels=labels,patch_artist=True)
    for patch,color in zip(box['boxes'],color):
        patch.set_facecolor(color)
    plt.title(f"Graph of price_range {n}")
    plt.show()

# %% [markdown]
# # 15. Relate between screen hight and width

# %%
import numpy as np
import matplotlib.pyplot as plt

x=df['sc_h'].sort_values().to_list()
y=df['sc_w'].sort_values().to_list()

firstx=x[:500]
firsty=y[:500]
secondx=x[500:1300]
secondy=y[500:1300]
thirdx=x[1300:]
thirdy=y[1300:]

Xvalues=firstx+secondx+thirdx
Yvalues=firsty+secondy+thirdy

cor=np.polyfit(Xvalues,Yvalues,1)
p=np.poly1d(cor)

# Set Values of color

col=['b']*len(firstx)+['g']*len(secondx)+['r']*len(thirdx)
# Plot values and line
plt.scatter(Xvalues,Yvalues,color=col)
plt.plot(Xvalues,p(Xvalues),'c--')
plt.title("Regression Line")
plt.xlabel("Screen_height")
plt.ylabel("Screen_width")
plt.grid()
plt.show()

# %% [markdown]
# # 16.  primary and front camera range with respect to the price_range

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,10))
pc=[df[df["price_range"]==0]["pc"].mean(),df[df["price_range"]==1]["pc"].mean(),df[df["price_range"]==2]["pc"].mean(),df[df["price_range"]==3]["pc"].mean()]
fc=[df[df["price_range"]==0]["fc"].mean(),df[df["price_range"]==1]["fc"].mean(),df[df["price_range"]==2]["fc"].mean(),df[df["price_range"]==3]["fc"].mean()]
index=np.arange(4)
width=0.30
plt.bar(index,pc,width,color='b',label="Primary camera mega pixels")
plt.bar(index,fc,width,color='r',label="Front camera mega pixels",bottom=pc)

plt.title("Vertically Stacked Bar Graph")
plt.xlabel("Price_range")
plt.ylabel("Pixel_values")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# # 17. Mobile weight depends upon which of the factors

# %%
import seaborn as sns
sns.heatmap(df[["mobile_wt","price_range","sc_h","sc_w","m_dep"]].corr(),cmap='coolwarm',annot=True,linecolor='white',linewidths=1)
# Out:
# <AxesSubplot:>
